# %% [markdown]
# # Variational Autoencoder in TensorFlow

# %%
import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.contrib.layers import xavier_initializer
import os.path

slim = tf.contrib.slim

# %%
# Import data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def log_bernoulli_with_logits(x, logits, eps=0.0, axis=-1):
    if eps > 0.0:
        max_val = np.log(1.0 - eps) - np.log(eps)
        logits = tf.clip_by_value(logits, -max_val, max_val,
                                  name='clipped_logit')
    return -tf.reduce_sum(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=x), axis)

def log_normal(x, mu, var, eps=0.0, axis=-1):
    if eps > 0.0:
        var = tf.add(var, eps, name='clipped_var')
    return -0.5 * tf.reduce_sum(
        tf.log(2 * np.pi) + tf.log(var) + tf.square(x - mu) / var, axis)

# %%
def qy_graph(x, k=10):
    """Network q(z|x)"""
    with slim.arg_scope([slim.fully_connected],
                    activation_fn=tf.nn.relu,
                    weights_initializer=xavier_initializer(),
                    biases_initializer=tf.zeros_initializer(),
                    reuse=tf.AUTO_REUSE):
        qy_logit = slim.fully_connected(x, 512, scope='fc1')
        qy_logit = slim.fully_connected(qy_logit, 512, scope='fc2')
        #add sbp_dropout layer in this
        qy_logit = slim.fully_connected(qy_logit, k, activation_fn=None, scope='logit')
        qy = tf.nn.softmax(qy_logit, name='prob')
    return qy_logit, qy

def qz_graph(x, y):
    with slim.arg_scope([slim.fully_connected],
                    activation_fn=tf.nn.relu,
                    weights_initializer=xavier_initializer(),
                    biases_initializer=tf.zeros_initializer(),
                    reuse=tf.AUTO_REUSE):
        mu_logvar = tf.concat([x,y],1, name='xy/concat')
        mu_logvar = slim.fully_connected(mu_logvar, 512, scope='fc3')
        mu_logvar = slim.fully_connected(mu_logvar, 512, scope='fc4')
        mu_logvar = slim.fully_connected(mu_logvar, 128, activation_fn=None, scope='fc5')
        mu, logvar = tf.split(mu_logvar, num_or_size_splits=2, axis=1)
        stddev = tf.sqrt(tf.exp(logvar))

        # Draw a z from the distribution
        epsilon = tf.random_normal(tf.shape(stddev))
        z = mu + tf.multiply(stddev, epsilon)
        return z, mu, logvar

# %%
def decoder(z, y):
    with slim.arg_scope([slim.fully_connected],
                        activation_fn=tf.nn.relu,
                        weights_initializer=xavier_initializer(),
                        biases_initializer=tf.zeros_initializer(),
                        reuse=tf.AUTO_REUSE): 
        # ---p(z)
        mu_logvar = slim.fully_connected(y, 128, activation_fn=None, scope='de_1')
        mu, logvar = tf.split(mu_logvar, num_or_size_splits=2, axis=1)
        # ---p(x)
        x_logit = slim.fully_connected(z, 512, scope='defc1')
        x_logit = slim.fully_connected(x_logit, 512, scope='defc2')
        x_logit = slim.fully_connected(x_logit, 784, activation_fn=None, scope='defc3')
        
    return mu, logvar, x_logit

# %%
def labeled_loss(x, px_logit, z, zm, zv, zm_prior, zv_prior):
    xy_loss = -log_bernoulli_with_logits(x, px_logit)
    xy_loss += log_normal(z, zm, zv) - log_normal(z, zm_prior, zv_prior)
    return xy_loss - np.log(0.1)

# %%
def test_acc(mnist, sess, qy_logit):
    logits = sess.run(qy_logit, feed_dict={'x:0': mnist.test.images})
    cat_pred = logits.argmax(1)
    real_pred = np.zeros_like(cat_pred)
    for cat in range(logits.shape[1]):
        idx = cat_pred == cat
        lab = mnist.test.labels.argmax(1)[idx]
        if len(lab) == 0:
            continue
        real_pred[cat_pred == cat] = mode(lab).mode[0]
    return np.mean(real_pred == mnist.test.labels.argmax(1))

# %%
def stream_print(f, string, pipe_to_file=True):
    print(string)
    if pipe_to_file and f is not None:
        f.write(string + '\n')
        f.flush()

# %%
def open_file(fname):
    if fname is None:
        return None
    else:
        i = 0
        while os.path.isfile('{:s}.{:d}'.format(fname, i)):
            i += 1
        return open('{:s}.{:d}'.format(fname, i), 'w')

# %%
def train(log_file, data, sess_info, epochs):
    (sess, qy_logit, nent, loss, train_step) = sess_info
    f = open_file(log_file)
    iterep = 500
    for i in range(iterep * epochs):
        sess.run(train_step, feed_dict={'x:0': mnist.train.next_batch(100)[0]})
        #message='i={:d}'.format(i + 1)
        #progbar(i, iterep, message)
        if (i + 1) % iterep == 0:
            a, b = sess.run([nent, loss], feed_dict=
                            {'x:0': mnist.train.images[np.random.choice(50000, 10000)]})
            c, d = sess.run([nent, loss], feed_dict={'x:0': mnist.test.images})
            a,b,c,d = -a.mean(), b.mean(), -c.mean(), d.mean()
            e = test_acc(mnist, sess, qy_logit)
            string = ('{:>10s},{:>10s},{:>10s},{:>10s},{:>10s},{:>10s}'
                      .format('tr_ent', 'tr_loss', 't_ent', 't_loss', 't_acc', 'epoch'))
            stream_print(f, string, i <= iterep)
            string = ('{:10.2e},{:10.2e},{:10.2e},{:10.2e},{:10.2e},{:10d}'
                      .format(a, b, c, d, e, (i + 1) // iterep))
            stream_print(f, string)
    if f is not None: 
        f.close()

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32,[None, 784], name='x')

# %%
with tf.name_scope('x_binarized'):
    xb = tf.cast(tf.greater(x, tf.random_uniform(tf.shape(x), 0, 1)), tf.float32)
with tf.name_scope('y_'):
    y_ = tf.fill(tf.stack([tf.shape(x)[0], 10]), 0.0)

# %%
qy_logit, qy = qy_graph(xb)

# %%
z, zm, zv, zm_prior, zv_prior, px_logit = [[None] * 10 for i in range(6)]
for i in range(10):
    with tf.name_scope('graphs/hot_at{:d}'.format(i)):
        y = tf.add(y_, tf.constant(np.eye(10)[i], dtype=tf.float32, name='hot_at_{:d}'.format(i)))
        z[i], zm[i], zv[i] = qz_graph(xb, y)
        zm_prior[i], zv_prior[i], px_logit[i] = decoder(z[i], y)

# %%
with tf.name_scope('loss'):
    with tf.name_scope('neg_entropy'):
        nent = tf.reduce_sum(qy * tf.nn.log_softmax(qy_logit), 1)
    losses = [None] * 10
    for i in range(10):
        with tf.name_scope('loss_at{:d}'.format(i)):
            losses[i] = labeled_loss(xb, px_logit[i], z[i], zm[i], tf.exp(zv[i]), zm_prior[i], tf.exp(zv_prior[i]))
    with tf.name_scope('final_loss'):
        loss = tf.add_n([nent] + [qy[:, i] * losses[i] for i in range(10)])

# %%
train_step = tf.train.AdamOptimizer().minimize(loss)
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
sess_info = (sess, qy_logit, nent, loss, train_step)
train('log/gmvae.log', mnist, sess_info, epochs=1000)
# Out:
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.13e+00,  1.26e+02,  2.13e+00,  1.24e+02,  3.88e-01,         1
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.09e+00,  1.12e+02,  2.09e+00,  1.11e+02,  3.64e-01,         2
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.97e+00,  1.07e+02,  1.97e+00,  1.06e+02,  3.78e-01,         3
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.93e+00,  1.04e+02,  1.92e+00,  1.03e+02,  3.87e-01,         4
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.81e+00,  1.02e+02,  1.81e+00,  1.02e+02,  3.69e-01,         5
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.81e+00,  1.01e+02,  1.80e+00,  1.01e+02,  3.51e-01,         6
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.74e+00,  9.96e+01,  1.73e+00,  9.97e+01,  3.83e-01,         7
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.70e+00,  9.83e+01,  1.69e+00,  9.89e+01,  3.87e-01,         8
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.58e+00,  9.76e+01,  1.57e+00,  9.84e+01,  3.83e-01,         9
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.64e+00,  9.80e+01,  1.63e+00,  9.80e+01,  3.87e-01,        10
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.57e+00,  9.66e+01,  1.58e+00,  9.73e+01,  4.10e-01,        11
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.55e+00,  9.67e+01,  1.55e+00,  9.73e+01,  4.24e-01,        12
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.52e+00,  9.59e+01,  1.51e+00,  9.69e+01,  4.30e-01,        13
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.42e+00,  9.61e+01,  1.41e+00,  9.66e+01,  4.19e-01,        14
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.39e+00,  9.61e+01,  1.38e+00,  9.65e+01,  4.25e-01,        15
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.38e+00,  9.56e+01,  1.37e+00,  9.62e+01,  4.49e-01,        16
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.34e+00,  9.47e+01,  1.33e+00,  9.61e+01,  4.60e-01,        17
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.25e+00,  9.52e+01,  1.24e+00,  9.61e+01,  4.75e-01,        18
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.21e+00,  9.49e+01,  1.20e+00,  9.58e+01,  4.89e-01,        19
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.18e+00,  9.48e+01,  1.17e+00,  9.61e+01,  4.97e-01,        20
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.07e+00,  9.48e+01,  1.06e+00,  9.57e+01,  5.07e-01,        21
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.70e-01,  9.51e+01,  9.66e-01,  9.61e+01,  5.21e-01,        22
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.45e-01,  9.48e+01,  8.44e-01,  9.61e+01,  5.26e-01,        23
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.19e-01,  9.43e+01,  8.14e-01,  9.54e+01,  5.37e-01,        24
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.67e-01,  9.45e+01,  7.58e-01,  9.54e+01,  5.52e-01,        25
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.18e-01,  9.47e+01,  7.14e-01,  9.56e+01,  5.61e-01,        26
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.39e-01,  9.47e+01,  6.33e-01,  9.56e+01,  5.83e-01,        27
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.18e-01,  9.44e+01,  6.20e-01,  9.53e+01,  5.96e-01,        28
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.57e-01,  9.40e+01,  5.66e-01,  9.55e+01,  6.03e-01,        29
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.31e-01,  9.36e+01,  5.31e-01,  9.51e+01,  6.18e-01,        30
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.20e-01,  9.37e+01,  5.30e-01,  9.51e+01,  6.33e-01,        31
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.80e-01,  9.39e+01,  4.84e-01,  9.53e+01,  6.41e-01,        32
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.16e-01,  9.39e+01,  4.22e-01,  9.51e+01,  6.35e-01,        33
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.31e-01,  9.36e+01,  4.35e-01,  9.50e+01,  6.55e-01,        34
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.81e-01,  9.38e+01,  3.75e-01,  9.50e+01,  6.55e-01,        35
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.60e-01,  9.33e+01,  3.69e-01,  9.50e+01,  6.59e-01,        36
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.48e-01,  9.41e+01,  3.50e-01,  9.52e+01,  6.74e-01,        37
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.35e-01,  9.34e+01,  3.36e-01,  9.47e+01,  6.62e-01,        38
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.36e-01,  9.36e+01,  3.38e-01,  9.50e+01,  6.76e-01,        39
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.20e-01,  9.30e+01,  3.25e-01,  9.48e+01,  6.78e-01,        40
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.29e-01,  9.36e+01,  3.32e-01,  9.50e+01,  6.74e-01,        41
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.18e-01,  9.34e+01,  3.23e-01,  9.49e+01,  6.79e-01,        42
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.15e-01,  9.29e+01,  3.20e-01,  9.48e+01,  6.86e-01,        43
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.06e-01,  9.29e+01,  3.12e-01,  9.44e+01,  6.86e-01,        44
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.87e-01,  9.31e+01,  2.95e-01,  9.46e+01,  6.93e-01,        45
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.79e-01,  9.28e+01,  2.92e-01,  9.49e+01,  7.08e-01,        46
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.68e-01,  9.31e+01,  2.79e-01,  9.49e+01,  7.03e-01,        47
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.57e-01,  9.31e+01,  2.68e-01,  9.49e+01,  7.09e-01,        48
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.57e-01,  9.31e+01,  2.64e-01,  9.45e+01,  7.22e-01,        49
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.60e-01,  9.32e+01,  2.64e-01,  9.47e+01,  7.26e-01,        50
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.45e-01,  9.35e+01,  2.48e-01,  9.48e+01,  7.21e-01,        51
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.46e-01,  9.27e+01,  2.58e-01,  9.46e+01,  7.29e-01,        52
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.52e-01,  9.30e+01,  2.59e-01,  9.43e+01,  7.29e-01,        53
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.33e-01,  9.25e+01,  2.35e-01,  9.44e+01,  7.39e-01,        54
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.24e-01,  9.29e+01,  2.27e-01,  9.44e+01,  7.25e-01,        55
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.25e-01,  9.20e+01,  2.30e-01,  9.44e+01,  7.37e-01,        56
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.40e-01,  9.17e+01,  2.47e-01,  9.43e+01,  7.40e-01,        57
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.21e-01,  9.24e+01,  2.27e-01,  9.41e+01,  7.38e-01,        58
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.31e-01,  9.20e+01,  2.35e-01,  9.43e+01,  7.46e-01,        59
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.14e-01,  9.23e+01,  2.26e-01,  9.43e+01,  7.37e-01,        60
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.25e-01,  9.19e+01,  2.28e-01,  9.40e+01,  7.42e-01,        61
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.10e-01,  9.25e+01,  2.20e-01,  9.43e+01,  7.41e-01,        62
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.14e-01,  9.25e+01,  2.21e-01,  9.42e+01,  7.46e-01,        63
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.23e-01,  9.23e+01,  2.22e-01,  9.39e+01,  7.49e-01,        64
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.08e-01,  9.24e+01,  2.17e-01,  9.41e+01,  7.64e-01,        65
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.01e-01,  9.27e+01,  2.05e-01,  9.41e+01,  7.57e-01,        66
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.08e-01,  9.22e+01,  2.14e-01,  9.40e+01,  7.69e-01,        67
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.93e-01,  9.25e+01,  2.04e-01,  9.43e+01,  7.67e-01,        68
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.11e-01,  9.23e+01,  2.19e-01,  9.42e+01,  7.70e-01,        69
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.89e-01,  9.21e+01,  1.96e-01,  9.39e+01,  7.67e-01,        70
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.97e-01,  9.21e+01,  2.08e-01,  9.39e+01,  7.65e-01,        71
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.02e-01,  9.19e+01,  2.07e-01,  9.40e+01,  7.78e-01,        72
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.88e-01,  9.25e+01,  1.97e-01,  9.43e+01,  7.81e-01,        73
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.89e-01,  9.14e+01,  1.96e-01,  9.41e+01,  7.81e-01,        74
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.72e-01,  9.15e+01,  1.79e-01,  9.41e+01,  7.91e-01,        75
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.90e-01,  9.22e+01,  1.96e-01,  9.41e+01,  7.88e-01,        76
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.90e-01,  9.19e+01,  1.96e-01,  9.39e+01,  7.95e-01,        77
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.76e-01,  9.20e+01,  1.81e-01,  9.40e+01,  7.91e-01,        78
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.75e-01,  9.14e+01,  1.78e-01,  9.39e+01,  7.97e-01,        79
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.71e-01,  9.18e+01,  1.74e-01,  9.42e+01,  8.05e-01,        80
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.73e-01,  9.18e+01,  1.80e-01,  9.39e+01,  8.06e-01,        81
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.65e-01,  9.16e+01,  1.71e-01,  9.39e+01,  8.04e-01,        82
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.64e-01,  9.17e+01,  1.66e-01,  9.40e+01,  8.03e-01,        83
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.55e-01,  9.18e+01,  1.61e-01,  9.40e+01,  8.14e-01,        84
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.68e-01,  9.18e+01,  1.71e-01,  9.39e+01,  8.13e-01,        85
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.52e-01,  9.17e+01,  1.54e-01,  9.37e+01,  8.21e-01,        86
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.58e-01,  9.16e+01,  1.64e-01,  9.36e+01,  8.21e-01,        87
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.53e-01,  9.21e+01,  1.58e-01,  9.41e+01,  8.19e-01,        88
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.52e-01,  9.14e+01,  1.59e-01,  9.37e+01,  8.22e-01,        89
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.47e-01,  9.13e+01,  1.50e-01,  9.37e+01,  8.11e-01,        90
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.33e-01,  9.17e+01,  1.41e-01,  9.37e+01,  8.28e-01,        91
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.39e-01,  9.15e+01,  1.43e-01,  9.38e+01,  8.29e-01,        92
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.29e-01,  9.18e+01,  1.33e-01,  9.39e+01,  8.16e-01,        93
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.37e-01,  9.16e+01,  1.45e-01,  9.40e+01,  8.29e-01,        94
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.28e-01,  9.20e+01,  1.36e-01,  9.36e+01,  8.26e-01,        95
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.38e-01,  9.12e+01,  1.40e-01,  9.39e+01,  8.23e-01,        96
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.47e-01,  9.13e+01,  1.49e-01,  9.35e+01,  8.25e-01,        97
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.25e-01,  9.11e+01,  1.30e-01,  9.36e+01,  8.35e-01,        98
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.30e-01,  9.18e+01,  1.33e-01,  9.39e+01,  8.37e-01,        99
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.23e-01,  9.11e+01,  1.20e-01,  9.34e+01,  8.35e-01,       100
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.26e-01,  9.15e+01,  1.32e-01,  9.37e+01,  8.34e-01,       101
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.20e-01,  9.13e+01,  1.27e-01,  9.37e+01,  8.31e-01,       102
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.08e-01,  9.14e+01,  1.15e-01,  9.35e+01,  8.34e-01,       103
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.20e-01,  9.14e+01,  1.21e-01,  9.35e+01,  8.37e-01,       104
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.24e-01,  9.13e+01,  1.28e-01,  9.34e+01,  8.38e-01,       105
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.29e-01,  9.14e+01,  1.36e-01,  9.37e+01,  8.40e-01,       106
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.21e-01,  9.19e+01,  1.26e-01,  9.37e+01,  8.36e-01,       107
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.25e-01,  9.16e+01,  1.26e-01,  9.36e+01,  8.47e-01,       108
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.10e-01,  9.13e+01,  1.15e-01,  9.36e+01,  8.49e-01,       109
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.19e-01,  9.09e+01,  1.27e-01,  9.38e+01,  8.41e-01,       110
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.15e-01,  9.13e+01,  1.21e-01,  9.35e+01,  8.34e-01,       111
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.04e-01,  9.10e+01,  1.10e-01,  9.36e+01,  8.47e-01,       112
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.08e-01,  9.11e+01,  1.14e-01,  9.34e+01,  8.43e-01,       113
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.02e-01,  9.10e+01,  1.09e-01,  9.35e+01,  8.39e-01,       114
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.01e-01,  9.13e+01,  1.06e-01,  9.35e+01,  8.47e-01,       115
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.03e-01,  9.12e+01,  1.08e-01,  9.35e+01,  8.41e-01,       116
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.02e-01,  9.10e+01,  1.05e-01,  9.36e+01,  8.49e-01,       117
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.07e-01,  9.07e+01,  1.10e-01,  9.32e+01,  8.47e-01,       118
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.05e-01,  9.13e+01,  1.08e-01,  9.34e+01,  8.53e-01,       119
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.42e-02,  9.12e+01,  9.96e-02,  9.34e+01,  8.42e-01,       120
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.09e-01,  9.10e+01,  1.06e-01,  9.34e+01,  8.48e-01,       121
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.06e-01,  9.05e+01,  1.08e-01,  9.33e+01,  8.57e-01,       122
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.01e-01,  9.08e+01,  1.08e-01,  9.33e+01,  8.52e-01,       123
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.01e-01,  9.11e+01,  1.07e-01,  9.35e+01,  8.56e-01,       124
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.05e-01,  9.12e+01,  1.09e-01,  9.33e+01,  8.54e-01,       125
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.03e-01,  9.05e+01,  1.09e-01,  9.33e+01,  8.51e-01,       126
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.87e-02,  9.09e+01,  1.03e-01,  9.30e+01,  8.55e-01,       127
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.18e-02,  9.13e+01,  9.61e-02,  9.34e+01,  8.52e-01,       128
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.48e-02,  9.14e+01,  9.70e-02,  9.34e+01,  8.53e-01,       129
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.99e-02,  9.10e+01,  1.02e-01,  9.37e+01,  8.52e-01,       130
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.67e-02,  9.05e+01,  1.02e-01,  9.34e+01,  8.55e-01,       131
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.25e-02,  9.10e+01,  9.75e-02,  9.32e+01,  8.57e-01,       132
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.77e-02,  9.04e+01,  1.04e-01,  9.33e+01,  8.56e-01,       133
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.84e-02,  9.08e+01,  9.46e-02,  9.31e+01,  8.58e-01,       134
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.15e-02,  9.14e+01,  9.36e-02,  9.33e+01,  8.62e-01,       135
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.99e-02,  9.10e+01,  9.57e-02,  9.32e+01,  8.60e-01,       136
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.74e-02,  9.06e+01,  9.77e-02,  9.32e+01,  8.61e-01,       137
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.64e-02,  9.12e+01,  9.53e-02,  9.33e+01,  8.61e-01,       138
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.54e-02,  9.05e+01,  9.40e-02,  9.32e+01,  8.62e-01,       139
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.08e-02,  9.06e+01,  9.41e-02,  9.33e+01,  8.59e-01,       140
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.97e-02,  9.06e+01,  9.37e-02,  9.31e+01,  8.64e-01,       141
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.78e-02,  9.05e+01,  9.20e-02,  9.32e+01,  8.58e-01,       142
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.75e-02,  9.11e+01,  8.91e-02,  9.32e+01,  8.61e-01,       143
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.07e-02,  9.07e+01,  8.95e-02,  9.32e+01,  8.67e-01,       144
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.57e-02,  9.11e+01,  8.88e-02,  9.34e+01,  8.64e-01,       145
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.26e-02,  9.06e+01,  8.50e-02,  9.34e+01,  8.65e-01,       146
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.85e-02,  9.10e+01,  8.52e-02,  9.32e+01,  8.64e-01,       147
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.22e-02,  9.07e+01,  8.63e-02,  9.31e+01,  8.68e-01,       148
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.04e-02,  9.08e+01,  8.42e-02,  9.33e+01,  8.72e-01,       149
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.05e-02,  9.10e+01,  8.34e-02,  9.32e+01,  8.67e-01,       150
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.31e-02,  9.05e+01,  7.53e-02,  9.32e+01,  8.65e-01,       151
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.79e-02,  9.11e+01,  7.76e-02,  9.34e+01,  8.65e-01,       152
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.78e-02,  9.04e+01,  8.26e-02,  9.33e+01,  8.70e-01,       153
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.34e-02,  9.09e+01,  8.70e-02,  9.32e+01,  8.65e-01,       154
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.14e-02,  9.07e+01,  8.78e-02,  9.32e+01,  8.71e-01,       155
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.29e-02,  9.01e+01,  8.48e-02,  9.33e+01,  8.74e-01,       156
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.67e-02,  9.02e+01,  7.96e-02,  9.31e+01,  8.69e-01,       157
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.68e-02,  8.97e+01,  8.21e-02,  9.30e+01,  8.74e-01,       158
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.14e-02,  9.07e+01,  7.26e-02,  9.33e+01,  8.75e-01,       159
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.60e-02,  9.05e+01,  7.51e-02,  9.30e+01,  8.73e-01,       160
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.48e-02,  9.10e+01,  7.53e-02,  9.32e+01,  8.75e-01,       161
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.88e-02,  9.02e+01,  7.95e-02,  9.32e+01,  8.71e-01,       162
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.32e-02,  9.06e+01,  8.03e-02,  9.34e+01,  8.72e-01,       163
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.29e-02,  9.06e+01,  8.21e-02,  9.33e+01,  8.74e-01,       164
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.74e-02,  9.08e+01,  8.03e-02,  9.32e+01,  8.80e-01,       165
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.05e-02,  9.06e+01,  7.41e-02,  9.30e+01,  8.75e-01,       166
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.83e-02,  9.02e+01,  7.41e-02,  9.29e+01,  8.73e-01,       167
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.72e-02,  9.04e+01,  7.34e-02,  9.31e+01,  8.76e-01,       168
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.62e-02,  9.12e+01,  8.14e-02,  9.31e+01,  8.74e-01,       169
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.51e-02,  9.01e+01,  8.02e-02,  9.31e+01,  8.77e-01,       170
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.93e-02,  9.02e+01,  7.50e-02,  9.30e+01,  8.77e-01,       171
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.60e-02,  9.06e+01,  7.23e-02,  9.32e+01,  8.76e-01,       172
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.21e-02,  9.05e+01,  7.87e-02,  9.30e+01,  8.75e-01,       173
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.88e-02,  9.02e+01,  7.51e-02,  9.28e+01,  8.86e-01,       174
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.31e-02,  9.03e+01,  6.81e-02,  9.30e+01,  8.82e-01,       175
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.36e-02,  9.01e+01,  7.02e-02,  9.30e+01,  8.79e-01,       176
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.87e-02,  9.01e+01,  7.25e-02,  9.32e+01,  8.86e-01,       177
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.49e-02,  9.03e+01,  6.77e-02,  9.31e+01,  8.79e-01,       178
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.56e-02,  9.06e+01,  6.58e-02,  9.29e+01,  8.85e-01,       179
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.22e-02,  9.01e+01,  6.92e-02,  9.29e+01,  8.82e-01,       180
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.53e-02,  9.04e+01,  7.04e-02,  9.30e+01,  8.85e-01,       181
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.61e-02,  9.07e+01,  6.78e-02,  9.33e+01,  8.82e-01,       182
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.84e-02,  9.08e+01,  7.29e-02,  9.32e+01,  8.77e-01,       183
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.71e-02,  8.99e+01,  6.38e-02,  9.29e+01,  8.83e-01,       184
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.94e-02,  9.02e+01,  6.41e-02,  9.30e+01,  8.81e-01,       185
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.04e-02,  9.05e+01,  6.23e-02,  9.34e+01,  8.85e-01,       186
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.20e-02,  9.05e+01,  6.35e-02,  9.32e+01,  8.88e-01,       187
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.11e-02,  9.01e+01,  6.26e-02,  9.29e+01,  8.82e-01,       188
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.08e-02,  9.05e+01,  6.52e-02,  9.30e+01,  8.81e-01,       189
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.32e-02,  8.99e+01,  6.59e-02,  9.29e+01,  8.88e-01,       190
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.31e-02,  9.06e+01,  6.53e-02,  9.31e+01,  8.88e-01,       191
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.66e-02,  9.04e+01,  7.00e-02,  9.32e+01,  8.84e-01,       192
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.45e-02,  9.04e+01,  6.87e-02,  9.29e+01,  8.87e-01,       193
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.54e-02,  9.04e+01,  6.00e-02,  9.29e+01,  8.89e-01,       194
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.03e-02,  8.99e+01,  6.43e-02,  9.30e+01,  8.87e-01,       195
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.42e-02,  9.01e+01,  6.66e-02,  9.30e+01,  8.89e-01,       196
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.06e-02,  8.99e+01,  6.28e-02,  9.28e+01,  8.91e-01,       197
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.57e-02,  9.07e+01,  5.98e-02,  9.30e+01,  8.89e-01,       198
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.12e-02,  9.04e+01,  6.40e-02,  9.33e+01,  8.91e-01,       199
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.49e-02,  9.02e+01,  5.77e-02,  9.30e+01,  8.93e-01,       200
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.67e-02,  9.03e+01,  5.83e-02,  9.29e+01,  8.94e-01,       201
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.34e-02,  8.99e+01,  5.94e-02,  9.29e+01,  8.96e-01,       202
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.18e-02,  9.04e+01,  5.59e-02,  9.29e+01,  8.89e-01,       203
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.45e-02,  9.00e+01,  5.85e-02,  9.31e+01,  8.82e-01,       204
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.65e-02,  8.98e+01,  6.04e-02,  9.27e+01,  8.94e-01,       205
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.34e-02,  8.97e+01,  6.02e-02,  9.30e+01,  8.90e-01,       206
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.60e-02,  9.02e+01,  6.18e-02,  9.29e+01,  8.90e-01,       207
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.99e-02,  9.00e+01,  6.16e-02,  9.28e+01,  8.94e-01,       208
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.78e-02,  9.02e+01,  5.94e-02,  9.30e+01,  8.91e-01,       209
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.53e-02,  9.05e+01,  5.73e-02,  9.31e+01,  8.92e-01,       210
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.59e-02,  9.03e+01,  5.88e-02,  9.30e+01,  8.94e-01,       211
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.83e-02,  9.02e+01,  6.27e-02,  9.30e+01,  8.96e-01,       212
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.67e-02,  9.02e+01,  5.65e-02,  9.28e+01,  8.90e-01,       213
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.69e-02,  9.03e+01,  5.71e-02,  9.29e+01,  8.90e-01,       214
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.46e-02,  9.03e+01,  5.05e-02,  9.27e+01,  8.95e-01,       215
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.99e-02,  9.01e+01,  5.42e-02,  9.30e+01,  8.93e-01,       216
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.44e-02,  8.99e+01,  5.50e-02,  9.27e+01,  8.94e-01,       217
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.66e-02,  9.01e+01,  5.26e-02,  9.29e+01,  8.96e-01,       218
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.62e-02,  8.95e+01,  4.98e-02,  9.30e+01,  8.90e-01,       219
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.71e-02,  9.00e+01,  5.94e-02,  9.28e+01,  8.93e-01,       220
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.46e-02,  9.04e+01,  5.84e-02,  9.31e+01,  8.97e-01,       221
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.84e-02,  8.94e+01,  5.14e-02,  9.27e+01,  9.00e-01,       222
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.51e-02,  8.95e+01,  5.64e-02,  9.28e+01,  8.94e-01,       223
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.73e-02,  9.04e+01,  5.09e-02,  9.26e+01,  8.97e-01,       224
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.78e-02,  9.03e+01,  5.17e-02,  9.31e+01,  8.99e-01,       225
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.43e-02,  8.99e+01,  5.35e-02,  9.28e+01,  9.00e-01,       226
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.32e-02,  9.05e+01,  4.66e-02,  9.28e+01,  9.00e-01,       227
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.06e-02,  8.98e+01,  5.61e-02,  9.28e+01,  9.00e-01,       228
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.95e-02,  9.00e+01,  5.26e-02,  9.28e+01,  9.03e-01,       229
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.88e-02,  8.94e+01,  5.38e-02,  9.28e+01,  9.06e-01,       230
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.81e-02,  9.03e+01,  4.84e-02,  9.26e+01,  9.00e-01,       231
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.89e-02,  9.00e+01,  4.88e-02,  9.29e+01,  8.94e-01,       232
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.45e-02,  8.99e+01,  5.00e-02,  9.28e+01,  8.98e-01,       233
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.68e-02,  8.99e+01,  4.93e-02,  9.31e+01,  8.96e-01,       234
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.36e-02,  8.93e+01,  4.84e-02,  9.29e+01,  8.99e-01,       235
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.48e-02,  9.01e+01,  4.88e-02,  9.26e+01,  9.02e-01,       236
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.32e-02,  8.98e+01,  4.88e-02,  9.29e+01,  9.05e-01,       237
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.15e-02,  8.96e+01,  4.43e-02,  9.27e+01,  9.05e-01,       238
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.07e-02,  9.02e+01,  4.65e-02,  9.29e+01,  9.00e-01,       239
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.04e-02,  9.01e+01,  4.21e-02,  9.28e+01,  8.99e-01,       240
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.31e-02,  8.98e+01,  4.75e-02,  9.28e+01,  9.05e-01,       241
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.15e-02,  8.97e+01,  4.55e-02,  9.28e+01,  9.06e-01,       242
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.20e-02,  8.97e+01,  4.33e-02,  9.26e+01,  9.06e-01,       243
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.28e-02,  9.03e+01,  4.64e-02,  9.31e+01,  9.00e-01,       244
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.84e-02,  9.01e+01,  4.45e-02,  9.30e+01,  9.02e-01,       245
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.00e-02,  9.02e+01,  4.24e-02,  9.27e+01,  9.06e-01,       246
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.95e-02,  8.96e+01,  4.36e-02,  9.29e+01,  8.99e-01,       247
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.93e-02,  8.97e+01,  4.41e-02,  9.28e+01,  9.07e-01,       248
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.83e-02,  8.99e+01,  4.13e-02,  9.28e+01,  9.02e-01,       249
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.96e-02,  9.01e+01,  4.09e-02,  9.29e+01,  9.12e-01,       250
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.94e-02,  8.99e+01,  4.31e-02,  9.27e+01,  9.04e-01,       251
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.73e-02,  9.02e+01,  4.11e-02,  9.28e+01,  9.04e-01,       252
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.85e-02,  8.99e+01,  4.46e-02,  9.28e+01,  9.08e-01,       253
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.72e-02,  8.99e+01,  4.19e-02,  9.29e+01,  9.04e-01,       254
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.57e-02,  8.97e+01,  3.92e-02,  9.28e+01,  9.02e-01,       255
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.72e-02,  8.95e+01,  4.12e-02,  9.27e+01,  9.05e-01,       256
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.75e-02,  8.95e+01,  3.68e-02,  9.27e+01,  9.09e-01,       257
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.89e-02,  8.93e+01,  4.11e-02,  9.26e+01,  9.05e-01,       258
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.62e-02,  8.98e+01,  3.93e-02,  9.30e+01,  9.06e-01,       259
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.46e-02,  8.99e+01,  3.63e-02,  9.30e+01,  9.08e-01,       260
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.42e-02,  8.98e+01,  3.68e-02,  9.26e+01,  9.10e-01,       261
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.50e-02,  8.97e+01,  3.70e-02,  9.30e+01,  9.09e-01,       262
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.38e-02,  9.02e+01,  3.59e-02,  9.30e+01,  9.08e-01,       263
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.60e-02,  8.95e+01,  3.85e-02,  9.25e+01,  9.07e-01,       264
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.77e-02,  9.00e+01,  4.02e-02,  9.27e+01,  9.12e-01,       265
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.59e-02,  8.99e+01,  4.21e-02,  9.29e+01,  9.03e-01,       266
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.73e-02,  8.95e+01,  4.09e-02,  9.26e+01,  9.11e-01,       267
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.30e-02,  9.01e+01,  3.69e-02,  9.27e+01,  9.12e-01,       268
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.56e-02,  8.98e+01,  3.76e-02,  9.27e+01,  9.11e-01,       269
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.64e-02,  8.99e+01,  3.77e-02,  9.28e+01,  9.12e-01,       270
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.66e-02,  8.99e+01,  3.91e-02,  9.29e+01,  9.08e-01,       271
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.64e-02,  9.01e+01,  4.04e-02,  9.27e+01,  9.06e-01,       272
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.72e-02,  8.99e+01,  3.76e-02,  9.27e+01,  9.09e-01,       273
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.81e-02,  8.96e+01,  4.24e-02,  9.27e+01,  9.09e-01,       274
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.45e-02,  9.00e+01,  4.08e-02,  9.29e+01,  9.10e-01,       275
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.49e-02,  8.95e+01,  3.73e-02,  9.28e+01,  9.05e-01,       276
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.53e-02,  8.97e+01,  3.76e-02,  9.29e+01,  9.08e-01,       277
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.28e-02,  8.97e+01,  3.66e-02,  9.26e+01,  9.10e-01,       278
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.22e-02,  8.90e+01,  3.52e-02,  9.26e+01,  9.08e-01,       279
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.25e-02,  8.97e+01,  3.72e-02,  9.29e+01,  9.12e-01,       280
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.50e-02,  9.00e+01,  3.64e-02,  9.29e+01,  9.17e-01,       281
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.15e-02,  9.00e+01,  3.29e-02,  9.27e+01,  9.11e-01,       282
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.96e-02,  8.96e+01,  3.38e-02,  9.27e+01,  9.14e-01,       283
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.13e-02,  8.96e+01,  3.30e-02,  9.25e+01,  9.14e-01,       284
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.10e-02,  8.94e+01,  3.56e-02,  9.26e+01,  9.10e-01,       285
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.86e-02,  9.02e+01,  3.31e-02,  9.26e+01,  9.17e-01,       286
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.03e-02,  8.96e+01,  3.57e-02,  9.26e+01,  9.12e-01,       287
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.22e-02,  9.00e+01,  3.56e-02,  9.27e+01,  9.12e-01,       288
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.06e-02,  8.94e+01,  3.30e-02,  9.26e+01,  9.14e-01,       289
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.10e-02,  8.96e+01,  3.53e-02,  9.26e+01,  9.10e-01,       290
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.38e-02,  8.96e+01,  3.58e-02,  9.29e+01,  9.17e-01,       291
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.29e-02,  8.96e+01,  3.55e-02,  9.27e+01,  9.17e-01,       292
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.09e-02,  8.92e+01,  3.17e-02,  9.26e+01,  9.13e-01,       293
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.08e-02,  9.04e+01,  3.17e-02,  9.28e+01,  9.18e-01,       294
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.96e-02,  8.96e+01,  3.14e-02,  9.26e+01,  9.17e-01,       295
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.73e-02,  8.97e+01,  3.25e-02,  9.28e+01,  9.11e-01,       296
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.87e-02,  8.95e+01,  3.10e-02,  9.28e+01,  9.15e-01,       297
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.70e-02,  9.01e+01,  3.12e-02,  9.27e+01,  9.16e-01,       298
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.92e-02,  8.94e+01,  3.16e-02,  9.27e+01,  9.14e-01,       299
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.28e-02,  8.97e+01,  3.55e-02,  9.27e+01,  9.18e-01,       300
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.85e-02,  8.96e+01,  3.07e-02,  9.27e+01,  9.14e-01,       301
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.15e-02,  8.96e+01,  3.39e-02,  9.27e+01,  9.13e-01,       302
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.92e-02,  8.95e+01,  3.31e-02,  9.24e+01,  9.14e-01,       303
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.75e-02,  8.93e+01,  3.15e-02,  9.26e+01,  9.19e-01,       304
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.21e-02,  8.98e+01,  3.37e-02,  9.27e+01,  9.14e-01,       305
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.09e-02,  8.91e+01,  3.17e-02,  9.25e+01,  9.17e-01,       306
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.94e-02,  8.96e+01,  3.00e-02,  9.27e+01,  9.16e-01,       307
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.93e-02,  8.97e+01,  3.01e-02,  9.26e+01,  9.12e-01,       308
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.94e-02,  8.99e+01,  3.03e-02,  9.27e+01,  9.18e-01,       309
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.68e-02,  8.93e+01,  2.99e-02,  9.28e+01,  9.17e-01,       310
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.72e-02,  8.94e+01,  2.95e-02,  9.26e+01,  9.15e-01,       311
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.58e-02,  8.98e+01,  2.72e-02,  9.27e+01,  9.17e-01,       312
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.68e-02,  8.94e+01,  2.78e-02,  9.26e+01,  9.15e-01,       313
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.91e-02,  8.91e+01,  3.11e-02,  9.27e+01,  9.20e-01,       314
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.63e-02,  8.97e+01,  2.92e-02,  9.28e+01,  9.16e-01,       315
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.63e-02,  8.94e+01,  2.90e-02,  9.27e+01,  9.14e-01,       316
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.62e-02,  8.96e+01,  2.82e-02,  9.30e+01,  9.22e-01,       317
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.42e-02,  8.94e+01,  3.14e-02,  9.25e+01,  9.21e-01,       318
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.52e-02,  8.94e+01,  2.91e-02,  9.25e+01,  9.17e-01,       319
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.75e-02,  8.96e+01,  2.97e-02,  9.26e+01,  9.20e-01,       320
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.67e-02,  8.92e+01,  3.08e-02,  9.25e+01,  9.20e-01,       321
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.56e-02,  8.93e+01,  2.72e-02,  9.25e+01,  9.20e-01,       322
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.93e-02,  8.95e+01,  2.95e-02,  9.29e+01,  9.22e-01,       323
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.55e-02,  8.94e+01,  2.76e-02,  9.25e+01,  9.22e-01,       324
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.41e-02,  8.98e+01,  2.66e-02,  9.26e+01,  9.22e-01,       325
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.51e-02,  8.95e+01,  2.72e-02,  9.26e+01,  9.22e-01,       326
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.42e-02,  8.98e+01,  2.84e-02,  9.26e+01,  9.20e-01,       327
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.49e-02,  8.93e+01,  2.97e-02,  9.27e+01,  9.25e-01,       328
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.56e-02,  8.94e+01,  2.75e-02,  9.24e+01,  9.20e-01,       329
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.75e-02,  8.88e+01,  2.81e-02,  9.25e+01,  9.22e-01,       330
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.26e-02,  8.95e+01,  2.46e-02,  9.24e+01,  9.20e-01,       331
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.72e-02,  8.94e+01,  2.95e-02,  9.26e+01,  9.22e-01,       332
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.32e-02,  8.92e+01,  2.69e-02,  9.25e+01,  9.21e-01,       333
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.27e-02,  8.95e+01,  2.64e-02,  9.26e+01,  9.21e-01,       334
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.17e-02,  8.93e+01,  2.33e-02,  9.27e+01,  9.24e-01,       335
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.56e-02,  8.94e+01,  2.71e-02,  9.27e+01,  9.21e-01,       336
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.15e-02,  8.97e+01,  2.43e-02,  9.23e+01,  9.24e-01,       337
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.32e-02,  8.96e+01,  2.54e-02,  9.24e+01,  9.25e-01,       338
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.33e-02,  9.00e+01,  2.33e-02,  9.26e+01,  9.23e-01,       339
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.96e-02,  8.90e+01,  2.55e-02,  9.26e+01,  9.25e-01,       340
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.18e-02,  8.93e+01,  2.64e-02,  9.26e+01,  9.24e-01,       341
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.33e-02,  8.98e+01,  2.70e-02,  9.27e+01,  9.25e-01,       342
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.29e-02,  8.91e+01,  2.54e-02,  9.27e+01,  9.21e-01,       343
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.09e-02,  8.94e+01,  2.39e-02,  9.26e+01,  9.23e-01,       344
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.96e-02,  8.91e+01,  2.31e-02,  9.26e+01,  9.26e-01,       345
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.89e-02,  8.96e+01,  2.34e-02,  9.27e+01,  9.27e-01,       346
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.03e-02,  8.95e+01,  2.22e-02,  9.24e+01,  9.23e-01,       347
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.96e-02,  8.97e+01,  2.30e-02,  9.27e+01,  9.24e-01,       348
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.28e-02,  8.95e+01,  2.42e-02,  9.25e+01,  9.23e-01,       349
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.23e-02,  8.94e+01,  2.34e-02,  9.30e+01,  9.22e-01,       350
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.82e-02,  8.93e+01,  2.14e-02,  9.25e+01,  9.26e-01,       351
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.85e-02,  8.97e+01,  2.31e-02,  9.23e+01,  9.23e-01,       352
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.74e-02,  8.91e+01,  1.92e-02,  9.25e+01,  9.23e-01,       353
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.85e-02,  8.92e+01,  2.40e-02,  9.28e+01,  9.23e-01,       354
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.74e-02,  8.91e+01,  2.21e-02,  9.24e+01,  9.24e-01,       355
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.92e-02,  8.96e+01,  2.19e-02,  9.30e+01,  9.26e-01,       356
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.91e-02,  8.92e+01,  2.18e-02,  9.27e+01,  9.26e-01,       357
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.77e-02,  8.94e+01,  2.21e-02,  9.26e+01,  9.25e-01,       358
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.89e-02,  8.95e+01,  2.21e-02,  9.26e+01,  9.27e-01,       359
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.66e-02,  8.94e+01,  2.22e-02,  9.25e+01,  9.30e-01,       360
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.56e-02,  8.96e+01,  2.00e-02,  9.29e+01,  9.28e-01,       361
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.78e-02,  8.97e+01,  2.12e-02,  9.27e+01,  9.30e-01,       362
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.64e-02,  8.95e+01,  1.90e-02,  9.26e+01,  9.33e-01,       363
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
# ...
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.00e-04,  8.82e+01,  1.69e-03,  9.22e+01,  9.50e-01,       880
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.54e-04,  8.83e+01,  1.16e-03,  9.24e+01,  9.48e-01,       881
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.63e-04,  8.85e+01,  1.61e-03,  9.23e+01,  9.47e-01,       882
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.81e-04,  8.89e+01,  1.25e-03,  9.25e+01,  9.49e-01,       883
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.32e-04,  8.81e+01,  1.22e-03,  9.21e+01,  9.49e-01,       884
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.53e-04,  8.81e+01,  9.77e-04,  9.22e+01,  9.49e-01,       885
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.85e-04,  8.87e+01,  1.41e-03,  9.22e+01,  9.46e-01,       886
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.47e-04,  8.85e+01,  1.42e-03,  9.22e+01,  9.48e-01,       887
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.22e-04,  8.84e+01,  9.81e-04,  9.24e+01,  9.48e-01,       888
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.54e-04,  8.82e+01,  9.32e-04,  9.21e+01,  9.49e-01,       889
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.21e-04,  8.80e+01,  1.53e-03,  9.22e+01,  9.45e-01,       890
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.44e-04,  8.84e+01,  1.29e-03,  9.24e+01,  9.46e-01,       891
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.92e-04,  8.85e+01,  1.68e-03,  9.23e+01,  9.47e-01,       892
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.68e-04,  8.84e+01,  1.07e-03,  9.23e+01,  9.48e-01,       893
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.21e-04,  8.83e+01,  1.34e-03,  9.23e+01,  9.47e-01,       894
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.20e-04,  8.86e+01,  9.22e-04,  9.23e+01,  9.50e-01,       895
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.50e-04,  8.80e+01,  1.22e-03,  9.23e+01,  9.48e-01,       896
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.89e-04,  8.83e+01,  1.30e-03,  9.23e+01,  9.47e-01,       897
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.23e-04,  8.80e+01,  1.62e-03,  9.22e+01,  9.46e-01,       898
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.58e-04,  8.85e+01,  1.12e-03,  9.25e+01,  9.46e-01,       899
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.48e-04,  8.86e+01,  1.36e-03,  9.25e+01,  9.45e-01,       900
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.51e-04,  8.84e+01,  1.25e-03,  9.25e+01,  9.47e-01,       901
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.77e-04,  8.87e+01,  1.09e-03,  9.21e+01,  9.48e-01,       902
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.75e-04,  8.83e+01,  1.12e-03,  9.22e+01,  9.46e-01,       903
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.83e-04,  8.81e+01,  9.68e-04,  9.20e+01,  9.48e-01,       904
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.25e-04,  8.81e+01,  1.23e-03,  9.21e+01,  9.47e-01,       905
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.92e-04,  8.84e+01,  8.08e-04,  9.22e+01,  9.48e-01,       906
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.90e-04,  8.86e+01,  8.52e-04,  9.23e+01,  9.49e-01,       907
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.44e-04,  8.85e+01,  9.31e-04,  9.21e+01,  9.50e-01,       908
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.52e-04,  8.83e+01,  1.20e-03,  9.21e+01,  9.49e-01,       909
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.61e-04,  8.81e+01,  1.21e-03,  9.23e+01,  9.50e-01,       910
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.63e-04,  8.82e+01,  1.24e-03,  9.22e+01,  9.50e-01,       911
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.16e-04,  8.88e+01,  9.50e-04,  9.23e+01,  9.48e-01,       912
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.46e-04,  8.85e+01,  9.12e-04,  9.24e+01,  9.51e-01,       913
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.04e-03,  8.80e+01,  1.12e-03,  9.21e+01,  9.47e-01,       914
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.78e-04,  8.84e+01,  1.51e-03,  9.20e+01,  9.46e-01,       915
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.54e-04,  8.84e+01,  1.06e-03,  9.22e+01,  9.49e-01,       916
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.25e-04,  8.87e+01,  1.24e-03,  9.24e+01,  9.47e-01,       917
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.19e-04,  8.87e+01,  8.21e-04,  9.24e+01,  9.50e-01,       918
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.22e-04,  8.80e+01,  1.21e-03,  9.22e+01,  9.50e-01,       919
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.12e-04,  8.83e+01,  9.69e-04,  9.22e+01,  9.49e-01,       920
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.20e-04,  8.83e+01,  8.30e-04,  9.24e+01,  9.49e-01,       921
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.24e-04,  8.82e+01,  5.76e-04,  9.21e+01,  9.47e-01,       922
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.16e-04,  8.85e+01,  7.81e-04,  9.22e+01,  9.50e-01,       923
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.53e-04,  8.84e+01,  1.11e-03,  9.19e+01,  9.47e-01,       924
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.10e-04,  8.85e+01,  1.16e-03,  9.22e+01,  9.46e-01,       925
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.94e-04,  8.84e+01,  8.21e-04,  9.21e+01,  9.49e-01,       926
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.61e-04,  8.82e+01,  6.83e-04,  9.22e+01,  9.44e-01,       927
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.19e-04,  8.84e+01,  1.10e-03,  9.23e+01,  9.49e-01,       928
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.08e-04,  8.81e+01,  7.06e-04,  9.25e+01,  9.47e-01,       929
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.11e-04,  8.84e+01,  1.31e-03,  9.22e+01,  9.47e-01,       930
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.96e-04,  8.87e+01,  1.29e-03,  9.25e+01,  9.48e-01,       931
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.77e-04,  8.82e+01,  1.25e-03,  9.23e+01,  9.49e-01,       932
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.64e-04,  8.82e+01,  1.14e-03,  9.23e+01,  9.49e-01,       933
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.75e-04,  8.82e+01,  1.13e-03,  9.22e+01,  9.49e-01,       934
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.80e-04,  8.88e+01,  1.09e-03,  9.23e+01,  9.44e-01,       935
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.08e-04,  8.81e+01,  1.05e-03,  9.21e+01,  9.47e-01,       936
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.03e-04,  8.87e+01,  1.23e-03,  9.24e+01,  9.50e-01,       937
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.18e-04,  8.81e+01,  1.13e-03,  9.23e+01,  9.51e-01,       938
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.58e-04,  8.86e+01,  5.44e-04,  9.24e+01,  9.50e-01,       939
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.17e-04,  8.84e+01,  1.32e-03,  9.23e+01,  9.49e-01,       940
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.09e-04,  8.88e+01,  9.13e-04,  9.24e+01,  9.51e-01,       941
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.48e-04,  8.83e+01,  7.91e-04,  9.22e+01,  9.49e-01,       942
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.80e-04,  8.88e+01,  1.14e-03,  9.23e+01,  9.49e-01,       943
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.37e-04,  8.85e+01,  9.64e-04,  9.22e+01,  9.50e-01,       944
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.15e-04,  8.87e+01,  1.14e-03,  9.22e+01,  9.51e-01,       945
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.21e-04,  8.88e+01,  7.99e-04,  9.22e+01,  9.49e-01,       946
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.17e-04,  8.82e+01,  1.12e-03,  9.22e+01,  9.49e-01,       947
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.54e-04,  8.84e+01,  6.10e-04,  9.25e+01,  9.48e-01,       948
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.68e-04,  8.84e+01,  8.64e-04,  9.22e+01,  9.51e-01,       949
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.30e-04,  8.84e+01,  7.81e-04,  9.23e+01,  9.47e-01,       950
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.12e-04,  8.81e+01,  9.40e-04,  9.22e+01,  9.49e-01,       951
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.46e-04,  8.83e+01,  1.14e-03,  9.23e+01,  9.48e-01,       952
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.51e-04,  8.82e+01,  4.62e-04,  9.24e+01,  9.47e-01,       953
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.57e-04,  8.87e+01,  8.02e-04,  9.24e+01,  9.50e-01,       954
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.63e-04,  8.83e+01,  8.25e-04,  9.24e+01,  9.51e-01,       955
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.19e-04,  8.83e+01,  8.89e-04,  9.20e+01,  9.51e-01,       956
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.56e-04,  8.83e+01,  1.21e-03,  9.21e+01,  9.50e-01,       957
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.31e-04,  8.85e+01,  1.04e-03,  9.23e+01,  9.50e-01,       958
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.28e-04,  8.82e+01,  8.95e-04,  9.24e+01,  9.48e-01,       959
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.88e-04,  8.88e+01,  6.86e-04,  9.24e+01,  9.45e-01,       960
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.35e-04,  8.87e+01,  9.06e-04,  9.23e+01,  9.48e-01,       961
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.85e-04,  8.81e+01,  1.24e-03,  9.22e+01,  9.47e-01,       962
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.28e-04,  8.81e+01,  1.20e-03,  9.22e+01,  9.48e-01,       963
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.22e-04,  8.88e+01,  4.95e-04,  9.22e+01,  9.50e-01,       964
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.92e-04,  8.87e+01,  6.75e-04,  9.23e+01,  9.48e-01,       965
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.35e-04,  8.86e+01,  1.04e-03,  9.27e+01,  9.49e-01,       966
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.11e-04,  8.78e+01,  1.13e-03,  9.22e+01,  9.46e-01,       967
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.13e-04,  8.86e+01,  1.03e-03,  9.22e+01,  9.51e-01,       968
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.88e-04,  8.87e+01,  1.05e-03,  9.23e+01,  9.51e-01,       969
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.02e-04,  8.82e+01,  1.06e-03,  9.24e+01,  9.51e-01,       970
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.21e-04,  8.88e+01,  8.67e-04,  9.22e+01,  9.48e-01,       971
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.28e-04,  8.86e+01,  1.09e-03,  9.22e+01,  9.49e-01,       972
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.43e-04,  8.85e+01,  1.40e-03,  9.23e+01,  9.50e-01,       973
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.82e-04,  8.86e+01,  1.46e-03,  9.23e+01,  9.49e-01,       974
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.15e-04,  8.85e+01,  1.04e-03,  9.20e+01,  9.48e-01,       975
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.18e-04,  8.90e+01,  7.46e-04,  9.22e+01,  9.49e-01,       976
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.76e-04,  8.83e+01,  8.48e-04,  9.24e+01,  9.45e-01,       977
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.05e-04,  8.86e+01,  1.18e-03,  9.23e+01,  9.48e-01,       978
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   2.52e-04,  8.88e+01,  1.04e-03,  9.21e+01,  9.49e-01,       979
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   9.85e-04,  8.85e+01,  1.23e-03,  9.25e+01,  9.43e-01,       980
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.98e-04,  8.80e+01,  5.83e-04,  9.23e+01,  9.48e-01,       981
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.93e-04,  8.80e+01,  8.01e-04,  9.21e+01,  9.50e-01,       982
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.59e-04,  8.83e+01,  9.00e-04,  9.23e+01,  9.47e-01,       983
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.53e-04,  8.85e+01,  1.10e-03,  9.21e+01,  9.50e-01,       984
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   7.01e-04,  8.85e+01,  6.96e-04,  9.21e+01,  9.49e-01,       985
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.06e-04,  8.85e+01,  1.15e-03,  9.22e+01,  9.50e-01,       986
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.23e-04,  8.82e+01,  9.26e-04,  9.23e+01,  9.50e-01,       987
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   8.22e-04,  8.82e+01,  1.16e-03,  9.23e+01,  9.50e-01,       988
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.41e-04,  8.82e+01,  1.12e-03,  9.22e+01,  9.50e-01,       989
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.75e-04,  8.84e+01,  9.30e-04,  9.22e+01,  9.45e-01,       990
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.36e-04,  8.82e+01,  1.02e-03,  9.23e+01,  9.46e-01,       991
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.03e-04,  8.87e+01,  9.40e-04,  9.26e+01,  9.49e-01,       992
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   3.45e-04,  8.83e+01,  9.51e-04,  9.20e+01,  9.51e-01,       993
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.44e-04,  8.84e+01,  7.79e-04,  9.23e+01,  9.49e-01,       994
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.71e-04,  8.84e+01,  5.60e-04,  9.22e+01,  9.47e-01,       995
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.87e-04,  8.82e+01,  1.28e-03,  9.22e+01,  9.48e-01,       996
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   4.39e-04,  8.85e+01,  1.10e-03,  9.23e+01,  9.47e-01,       997
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   6.40e-04,  8.86e+01,  1.05e-03,  9.23e+01,  9.46e-01,       998
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   1.44e-04,  8.82e+01,  4.16e-04,  9.24e+01,  9.49e-01,       999
#     tr_ent,   tr_loss,     t_ent,    t_loss,     t_acc,     epoch
#   5.15e-04,  8.79e+01,  6.81e-04,  9.22e+01,  9.48e-01,      1000
